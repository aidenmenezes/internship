# %% [markdown]
# Date: 6-4-26

# %%
import cv2

img = cv2.imread("bunny.png")

print("Shape:", img.shape)
print("Pixel Value:", img[0,0])

print("Number of Channels:", img.shape[2])
# Out:
# Shape: (188, 193, 3)
# Pixel Value: [226 222 254]
# Number of Channels: 3
