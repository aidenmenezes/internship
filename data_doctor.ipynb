# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "alice", "Charlie", "Bob"],
    "Age": [25, np.nan, 25, 30, np.nan],
    "City": ["hyderabad", "HYDERABAD", "Hyderabad", "mumbai", "Mumbai"],
    "Salary": [50000, 60000, 50000, np.nan, 60000]
}

df = pd.DataFrame(data)

print("Original Dataset:\n")
print(df)


df = df.drop_duplicates()


df["Age"].fillna(df["Age"].mean(), inplace=True)
df["Salary"].fillna(df["Salary"].mean(), inplace=True)


df["Name"] = df["Name"].str.capitalize()
df["City"] = df["City"].str.lower().str.capitalize()

print("\nCleaned Dataset:\n")
print(df)
# Out:
# Original Dataset:
#
#       Name   Age       City   Salary
# 0    Alice  25.0  hyderabad  50000.0
# 1      Bob   NaN  HYDERABAD  60000.0
# 2    alice  25.0  Hyderabad  50000.0
# 3  Charlie  30.0     mumbai      NaN
# 4      Bob   NaN     Mumbai  60000.0
#
# Cleaned Dataset:
#
#       Name        Age       City   Salary
# 0    Alice  25.000000  Hyderabad  50000.0
# 1      Bob  26.666667  Hyderabad  60000.0
# 2    Alice  25.000000  Hyderabad  50000.0
# 3  Charlie  30.000000     Mumbai  55000.0
# 4      Bob  26.666667     Mumbai  60000.0
