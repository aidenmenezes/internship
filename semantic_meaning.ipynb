# %% [markdown]
# Examples of Word Pairs
# Car – Vehicle → Highly similar
# Happy – Joyful → Similar meaning
# Big – Large → Nearly same meaning
# Hot – Cold → Opposite meaning (low similarity)
# Teacher – Student → Related but different roles
