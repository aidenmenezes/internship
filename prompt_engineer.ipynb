# %% [markdown]
# Resume
#
# Weak Prompt:
# “Make my resume”
#
# Strong Prompt:
# “Create a professional resume for a final-year computer science student with skills in Python, Machine Learning, and projects in data analysis. Include education, skills, projects, and internships.”
#
# Business Idea
#
# Weak Prompt:
# “Give business idea”
#
# Strong Prompt:
# “Suggest a startup idea for college students that requires low investment and uses AI or technology. Include target audience, features, and revenue model.”
#
# Study Plan
#
# Weak Prompt:
# “Help me study”
#
# Strong Prompt:
# “Create a 2-week study plan for learning Machine Learning basics, including daily topics, practice tasks, and revision time.”
#
# Email Writing
#
# Weak Prompt:
# “Write email”
#
# Strong Prompt:
# “Write a formal email to a company requesting an internship opportunity in data science, highlighting my skills in Python and machine learning.”
#
# Coding Help
#
# Weak Prompt:
# “Fix my code”
#
# Strong Prompt:
# “Debug this Python code that gives an index error and explain what caused the issue and how to fix it.”
#
# Essay Writing
#
# Weak Prompt:
# “Write essay”
#
# Strong Prompt:
# “Write a 300-word essay on the importance of Artificial Intelligence in healthcare with examples and future impact.”
#
# Project Idea
#
# Weak Prompt:
# “Give project”
#
# Strong Prompt:
# “Suggest a final-year machine learning project related to healthcare, including dataset, algorithm, and expected outcome.”
#
# Comparison
# Weak Prompts:
# Vague and unclear
# Lack details
# Produce generic or incomplete responses
# Strong Prompts:
# Clear and specific
# Provide context and requirements
# Produce accurate, detailed, and useful responses
