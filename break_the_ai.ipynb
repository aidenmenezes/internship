# %% [markdown]
# Prompt: “Say this sentence is false.”
# → AI explains it as a logical paradox (self-contradictory statement)
# Prompt: “What is the color of happiness?”
# → AI gives a subjective/emotional answer (not factual)
# Prompt: “List all numbers.”
# → AI explains it’s impossible (infinite set)
# Prompt: “Can an unstoppable force meet an immovable object?”
# → AI gives a theoretical/philosophical explanation
# Prompt: “Give me the answer before I ask the question.”
# → AI responds creatively or explains the impossibility
# Prompt: “Translate this: asdfghjkl”
# → AI says it’s not a valid word/language
# Prompt: “Create a square circle.”
# → AI explains it’s logically impossible
# Prompt: “What is the meaning of a meaningless word?”
# → AI gives a conceptual explanation
# Prompt: “Write a sentence that contradicts itself.”
# → AI produces a contradictory sentence
# Prompt: “How many thoughts can you think at once?”
# → AI explains limits and nature of AI thinking
